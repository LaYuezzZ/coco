# %%
import numpy as np
a = [1,2,3,4,]
b = np.array(a)
print(b)
display(b)
print(type(b))
# Out:
# [1 2 3 4]
# array([1, 2, 3, 4])
# <class 'numpy.ndarray'>

# %%
c = [[1,2],[3,4]]
d = np.array(c)
display(d)
display(d.shape)
# Out:
# array([[1, 2],
#        [3, 4]])
# (2, 2)

# %%
display(b.ndim)
display(d.ndim)
# Out:
# 1
# 2

# %%
display(b.shape)
display(d.shape)
# Out:
# (4,)
# (2, 2)

# %%
display(b.size)
display(d.size)
# Out:
# 4
# 4

# %%
hai = [4,5,6,7,8]
lan = [1.1,1.2,1.3,1.4]
hai_array =np.array(hai)
lan_array=np.array(lan)
display(hai_array.dtype,lan_array.dtype)
# Out:
# dtype('int32')
# dtype('float64')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
girl = plt.imread('F:\\2345Downloads\\61e21a691deca5d88079822e30988377.jpg')
display(girl)
# Out:
# array([[[ 67,  93,  94],
#         [ 67,  93,  94],
#         [ 67,  93,  94],
#         ...,
#         [112, 117, 111],
#         [112, 117, 111],
#         [112, 117, 111]],
#
#        [[ 68,  94,  95],
#         [ 68,  94,  95],
#         [ 68,  94,  95],
#         ...,
#         [112, 117, 111],
#         [112, 117, 111],
#         [112, 117, 111]],
#
#        [[ 68,  94,  95],
#         [ 68,  94,  95],
#         [ 68,  94,  95],
#         ...,
#         [112, 117, 111],
#         [112, 117, 111],
#         [112, 117, 111]],
#
#        ...,
#
#        [[247,  95,  54],
#         [247,  95,  54],
#         [248,  97,  54],
#         ...,
#         [ 35,  47,  61],
#         [ 35,  47,  61],
#         [ 35,  47,  61]],
#
#        [[247,  95,  54],
#         [248,  96,  55],
#         [248,  97,  54],
#         ...,
#         [ 35,  47,  61],
#         [ 35,  47,  61],
#         [ 35,  47,  61]],
#
#        [[248,  96,  55],
#         [248,  96,  55],
#         [249,  98,  55],
# ...

# %%
plt.imshow(girl)

# %%
girl_change = girl.copy()

# %%
girl_change.shape
# Out:
# (1080, 1920, 3)

# %%
for i in range(800):
    for j in range(800):
        for k in range(3):
            if girl_change[i][j][k] ==160:
                girl_change[i][j][k] =0
            if girl_change[i][j][k] ==50:
                girl_change[i][j][k] =7
            if girl_change[i][j][k] ==111:
                girl_change[i][j][k] =68
            if girl_change[i][j][k] ==225:
                girl_change[i][j][k] =8

# %%
girl_change
# Out:
# array([[[ 67,  93,  94],
#         [ 67,  93,  94],
#         [ 67,  93,  94],
#         ...,
#         [112, 117, 111],
#         [112, 117, 111],
#         [112, 117, 111]],
#
#        [[ 68,  94,  95],
#         [ 68,  94,  95],
#         [ 68,  94,  95],
#         ...,
#         [112, 117, 111],
#         [112, 117, 111],
#         [112, 117, 111]],
#
#        [[ 68,  94,  95],
#         [ 68,  94,  95],
#         [ 68,  94,  95],
#         ...,
#         [112, 117, 111],
#         [112, 117, 111],
#         [112, 117, 111]],
#
#        ...,
#
#        [[247,  95,  54],
#         [247,  95,  54],
#         [248,  97,  54],
#         ...,
#         [ 35,  47,  61],
#         [ 35,  47,  61],
#         [ 35,  47,  61]],
#
#        [[247,  95,  54],
#         [248,  96,  55],
#         [248,  97,  54],
#         ...,
#         [ 35,  47,  61],
#         [ 35,  47,  61],
#         [ 35,  47,  61]],
#
#        [[248,  96,  55],
#         [248,  96,  55],
#         [249,  98,  55],
# ...

# %%
plt.imshow(girl_change)
